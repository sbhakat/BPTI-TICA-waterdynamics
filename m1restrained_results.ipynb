# %%
%gnuplot inline pngcairo font "Arial,12" size 600,400
reset
set xlabel 'tIC1'
set ylabel 'FW (nm)'
set cbrange [-25:25]
set xrange [-0.001:0.008]
set yrange [0.15:0.66]
set cblabel 'Free Energy (kJ/mol)'

set pm3d map
set contour base
 
set cntrparam levels incr -25,5,25
set palette rgbformulae 33,13,10
set palette maxcolors 12

sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_fw.dat' u 1:2:3 notitle
# Out:
# reset
# set xlabel 'TIC1'
# set ylabel 'FW (nm)'
# set cbrange [-25:25]
# set xrange [-0.001:0.008]
# set yrange [0.15:0.66]
# set cblabel 'Free Energy (kJ/mol)'
#
# set pm3d map
# set contour base
#
# set cntrparam levels incr -25,5,25
# set palette rgbformulae 33,13,10
# set palette maxcolors 12
#
# set output '/tmp/gnuplot-inline-1587773438.2726965.994256398426.png'
# sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_fw.dat' u 1:2:3 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
%gnuplot inline pngcairo font "Arial,12" size 600,400
reset
set xlabel 'TIC1 '
set ylabel 'SW (nm)'
set cbrange [-25:25]
set xrange [-0.001:0.008]
set yrange [0.15:0.66]
set cblabel 'Free Energy (kJ/mol)'

set pm3d map
set contour base
 
set cntrparam levels incr -25,5,25
set palette rgbformulae 33,13,10
set palette maxcolors 12

sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_sw.dat' u 1:2:3 notitle
# Out:
# reset
# set xlabel 'TIC1 '
# set ylabel 'SW (nm)'
# set cbrange [-25:25]
# set xrange [-0.001:0.008]
# set yrange [0.15:0.66]
# set cblabel 'Free Energy (kJ/mol)'
#
# set pm3d map
# set contour base
#
# set cntrparam levels incr -25,5,25
# set palette rgbformulae 33,13,10
# set palette maxcolors 12
#
# set output '/tmp/gnuplot-inline-1587773451.2163134.90307848131.png'
# sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_sw.dat' u 1:2:3 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
%gnuplot inline pngcairo font "Arial,12" size 600,400
reset
set xlabel 'Ile18 FW (nm)'
set ylabel 'Free energy (kJ/mol)'

p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_fw.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set xlabel 'Ile18 FW (nm)'
# set ylabel 'Free energy (kJ/mol)'
#
# set output '/tmp/gnuplot-inline-1587773457.9464526.353964609351.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_fw.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
reset
set ylabel 'Ile18 solvated - nonsolvated FE diff (kJ/mol)'
set xlabel 'Time (ns)'
p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_fw.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set ylabel 'Ile18 solvated - nonsolvated FE diff (kJ/mol)'
# set xlabel 'Time (ns)'
# set output '/tmp/gnuplot-inline-1587773472.617833.581044304467.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_fw.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
%gnuplot inline pngcairo font "Arial,12" size 600,400
reset
set xlabel 'TIC1'
set ylabel 'Free energy (kJ/mol)'

p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_tic1.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set xlabel 'TIC1'
# set ylabel 'Free energy (kJ/mol)'
#
# set output '/tmp/gnuplot-inline-1587773515.2374942.71289881434.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_tic1.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
%gnuplot inline pngcairo font "Arial,12" size 600,400
reset
set ylabel 'TIC1 left-right FE diff (kJ/mol)'
set xlabel 'Time (ns)'

p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_tic1.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set ylabel 'TIC1 left-right FE diff (kJ/mol)'
# set xlabel 'Time (ns)'
#
# set output '/tmp/gnuplot-inline-1587773534.8534791.996261736837.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_tic1.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
# unset output

# %%
reset
set xlabel 'Hbond (nm)'
set ylabel 'Free energy (kJ/mol)'
p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_hbond.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set xlabel 'Hbond (nm)'
# set ylabel 'Free energy (kJ/mol)'
# set output '/tmp/gnuplot-inline-1587773556.0384314.732036168435.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/fes1d_hbond.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %% [markdown]
# Hbond convergence curve looks strange, trying to understand that. Here are a few profiles:

# %%
reset
set xlabel 'Hbond (nm)'
set ylabel 'Free energy (kJ/mol)'
p '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.40.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.80.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.120.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.160.fes1d_hbond.dat' u 1:2 w l lw 2 notitle,\
'~/Pkeb/BPTI/PTMETAD/Reweight/analysis.200.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.230.fes1d_hbond.dat' u 1:2 w l lw 2 notitle
# Out:
# reset
# set xlabel 'Hbond (nm)'
# set ylabel 'Free energy (kJ/mol)'
# set output '/tmp/gnuplot-inline-1587827970.8003519.949667865156.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.40.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.80.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.120.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.160.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.200.fes1d_hbond.dat' u 1:2 w l lw 2 notitle, '~/Pkeb/BPTI/PTMETAD/Reweight/analysis.230.fes1d_hbond.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %% [markdown]
# And the fluctuation with time:   (everything looks fine so unclear why the convergence curve is so flat)

# %%
reset
set ylabel 'Hbond (nm)'
set xlabel 'Time (ns)'
p '~/Pkeb/BPTI/PTMETAD/Reweight/COLVAR_sparse' u ($0*0.01):8 w l lw 2 notitle
# Out:
# reset
# set ylabel 'Hbond (nm)'
# set xlabel 'Time (ns)'
# set output '/tmp/gnuplot-inline-1587828414.9155338.327465180112.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/COLVAR_sparse' u ($0*0.01):8 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output

# %%
reset
set xlabel 'Hbond (nm) '
set ylabel 'FW (nm)'
set cbrange [-25:25]
set xrange [0.25:0.70]
set yrange [0.15:0.66]
set cblabel 'Free Energy (kJ/mol)'

set pm3d map
set contour base
 
set cntrparam levels incr -25,5,25
set palette rgbformulae 33,13,10
set palette maxcolors 12

sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_hfw.dat' u 1:2:3 notitle
# Out:
# reset
# set xlabel 'Hbond (nm) '
# set ylabel 'FW (nm)'
# set cbrange [-25:25]
# set xrange [0.25:0.70]
# set yrange [0.15:0.66]
# set cblabel 'Free Energy (kJ/mol)'
#
# set pm3d map
# set contour base
#
# set cntrparam levels incr -25,5,25
# set palette rgbformulae 33,13,10
# set palette maxcolors 12
#
# set output '/tmp/gnuplot-inline-1587773565.7866535.321532274475.png'
# sp '~/Pkeb/BPTI/PTMETAD/Reweight/fes_hfw.dat' u 1:2:3 notitle

# %%
reset
set ylabel 'Ile18 Hbond FE diff (kJ/mol)'
set xlabel 'Time (ns)'
p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_hbond.dat' u 1:2 w l lw 2 notitle
# Out:
# unset output
#  reset
# set ylabel 'Ile18 Hbond FE diff (kJ/mol)'
# set xlabel 'Time (ns)'
# set output '/tmp/gnuplot-inline-1587773585.3935788.943193549979.png'
# p '~/Pkeb/BPTI/PTMETAD/Reweight/conv_hbond.dat' u 1:2 w l lw 2 notitle
#
#
#
#
#
#
#
#
# unset output
